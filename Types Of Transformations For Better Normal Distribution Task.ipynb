# %%
import numpy as np
import pandas as pd
import scipy.stats as spss
import plotly.express as px
import seaborn as sns

# %% [markdown]
# # Types Of Transformations For Better Normal Distribution
#
#     Numerical variables may have high skewed and non-normal distribution caused by outliers,highly exponential distribution.Therefore we go for data transformation. Here are the types of transformations for better normal distribution that will be applied on an Exponintial distribution as an example:
#
#
#     1-Log Transformation
#     2-Square-Root Transformation
#     3-Reciprocal Transformation
#     4-Box-Cox Transformation
#     5-Yeo-Johnson Transformation (Bonus)

# %% [markdown]
# ## **The Original Distribution**

# %%
Exponential = spss.expon.rvs(scale=1,loc=0,size=1000) # size specifies number of random variates, loc corresponds to mean, scale corresponds to standard deviation
EX=sns.distplot(Exponential, kde=True, color="SkyBlue",hist= False)
EX.set(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Density')]

# %% [markdown]
# ## Log Transformation :
#
# In Log transformation each variable of x will be replaced by log(x) with base 10, base 2, or natural log.

# %%
log_target = np.log1p(Exponential)
log_trans=sns.distplot(log_target, kde=True, color="red",hist= False)
log_trans(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10056/1645593021.py in <module>
#       1 log_target = np.log1p(Exponential)
#       2 log_trans=sns.distplot(log_target, kde=True, color="red",hist= False)
# ----> 3 log_trans(xlabel='Exponential Distribution', ylabel='Density')
#
# TypeError: 'AxesSubplot' object is not callable

# %% [markdown]
# ## Square-Root Transformation :
#
# 1- This transformation will give a moderate effect on distribution.
#
# 2- The main advantage of square root transformation is, it can be applied to zero values.

# %%
sqrt_target=(Exponential)**(1/2)
sqrt_trans=sns.distplot(sqrt_target, kde=True, color="green",hist= False)
sqrt_trans(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10056/3932877169.py in <module>
#       1 sqrt_target=(Exponential)**(1/2)
#       2 sqrt_trans=sns.distplot(sqrt_target, kde=True, color="green",hist= False)
# ----> 3 sqrt_trans(xlabel='Exponential Distribution', ylabel='Density')
#
# TypeError: 'AxesSubplot' object is not callable

# %% [markdown]
# ## Reciprocal Transformation :
#
# 1-In this transformation, x will replace by the inverse of x (1/x).
#
# 2- The reciprocal transformation will give little effect on the shape of the distribution.
#
# 3-This transformation can be only used for non-zero values.

# %%
reciprocal_target= 1/(Exponential)
reciprocal_trans=sns.distplot(reciprocal_target, kde=True, color="orange",hist= False)
reciprocal_trans(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10056/3302099092.py in <module>
#       1 reciprocal_target= 1/(Exponential)
#       2 reciprocal_trans=sns.distplot(reciprocal_target, kde=True, color="orange",hist= False)
# ----> 3 reciprocal_trans(xlabel='Exponential Distribution', ylabel='Density')
#
# TypeError: 'AxesSubplot' object is not callable

# %% [markdown]
# ## Box-Cox Transformation:
#
# 1-A Box Cox transformation is a transformation of non-normal dependent variables into a normal shape. Normality is an important assumption for many statistical techniques; if your data is not normal, applying a Box-Cox means that you are able to run a broader number of tests.
#
# 2-At the core of the Box Cox transformation is an exponent, lambda (λ), which varies from -5 to 5. All values of λ are considered and the optimal value for your data is selected; The “optimal value” is the one which results in the best approximation of a normal distribution curve. The transformation of Y has the form:

# %%
from IPython.display import Image
Image(filename="C:/Users/MBR/Desktop/uuu.png", width=400 , height=400)

# %% [markdown]
# 3-This test only works for positive data. However, Box and Cox did propose a second formula that can be used for negative y-values:

# %%
Image(filename="C:/Users/MBR/Desktop/hhh.png", width=400 , height=400)

# %%
from scipy.stats import boxcox
bcx_target, lam = boxcox(Exponential)
#lam is the best lambda for the distribution
bcx_trans=sns.distplot(bcx_target, kde=True, color="black",hist= False)
bcx_trans(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10056/919312708.py in <module>
#       3 #lam is the best lambda for the distribution
#       4 bcx_trans=sns.distplot(bcx_target, kde=True, color="black",hist= False)
# ----> 5 bcx_trans(xlabel='Exponential Distribution', ylabel='Density')
#
# TypeError: 'AxesSubplot' object is not callable

# %% [markdown]
# ## Yeo-Johnson Transformation:
#
# This is one of the older transformation technique which is very similar to Box-cox transformation but does not require the values to be strictly positive.
#
# This transformation is also having the ability to make the distribution more symmetric.

# %%
from scipy.stats import yeojohnson
yf_target, lam = yeojohnson(Exponential)
yf_trans=sns.distplot(yf_target, kde=True, color="orange",hist= False)
yf_trans(xlabel='Exponential Distribution', ylabel='Density')
# Out:
# C:\Users\MBR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10056/2355562738.py in <module>
#       2 yf_target, lam = yeojohnson(Exponential)
#       3 yf_trans=sns.distplot(yf_target, kde=True, color="orange",hist= False)
# ----> 4 yf_trans(xlabel='Exponential Distribution', ylabel='Density')
#
# TypeError: 'AxesSubplot' object is not callable
