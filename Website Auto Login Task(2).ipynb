# %%
from selenium import webdriver
import time

username=input("Enter your Email: ")
password=input("Enter your Password: ")
driver= webdriver.Chrome("D:\AI-Course\Py.Prac\\chromedriver.exe")
driver.get("https://github.com/")


driver.maximize_window()
LogIn=driver.find_element_by_link_text("Sign in")
LogIn.click()

User_name=driver.find_element_by_id("login_field")
User_name.send_keys(username)

User_password=driver.find_element_by_id("password")
User_password.send_keys(password)

button=driver.find_element_by_class_name("js-sign-in-button") #From the html of the website
button.click()
time.sleep(3)

# %%
URL="https://www.github.com/"
Name_XPath='//*[@id="login_feild"]'
Pass_XPath='//*[@id="PassWord"]'

def Auto_LogIn():
    username=input("Enter your Email: ")
    password=input("Enter your Password: ")
    driver= webdriver.Chrome("D:\AI-Course\Py.Prac\\chromedriver.exe")
    driver.get("https://github.com/")


    driver.maximize_window()
    log=driver.find_element_by_link_text("Sign in")
    log.click()

    user_name=driver.find_element_by_Xpath(Name_XPath)
    user_name.send_keys(username)

    user_password=driver.find_element_by_Xpath(Pass_XPath)
    user_password.send_keys(password)

    button=driver.find_element_by_class_name("js-sign-in-button")
    button.click()
    time.sleep(3)
Auto_LogIn()
