# %% [markdown]
# ### How to display a colored image by matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread("C:/Users/MBR/Desktop/images.jpg")
plt.imshow(image)
plt.show()
