# %% [markdown]
# # Types Of Statistical Tests

# %% [markdown]
# ## Z-Test

# %% [markdown]
# ### Z Test Definition
#
# A z test is conducted on a population that follows a normal distribution with independent data points and has a sample size that is greater than or equal to 30. It is used to check whether the means of two populations are equal to each other when the population variance is known. The null hypothesis of a z test can be rejected if the z test statistic is statistically significant when compared with the critical value.

# %% [markdown]
# ### Z Test Formula
# The z test formula to set up the required hypothesis tests for a one sample and a two-sample z test are given below.

# %% [markdown]
# #### One-Sample Z Test
#
# A one-sample z test is used to check if there is a difference between the sample mean and the population mean when the population standard deviation is known. The formula for the z test statistic is given as follows:

# %%
from IPython.display import Image
Image(filename="C:/Users/MBR/Desktop/bb.png", width=400 , height=400)

# %% [markdown]
# **Where:**
#
#  **x̄** is the mean of the sample.
#
#  **µ** is the assumed mean.
#
#  **σ** is the standard deviation.
#
#  **n** is the number of observations.
#
#
# **The algorithm to set a one sample z test based on the z test statistic is given as follows:**
#
# **1-Left Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ<μ0
#
# **Decision Criteria:** If the z statistic < z critical value then reject the null hypothesis.
#
# **2-Right Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ>μ0
#
# **Decision Criteria:** If the z statistic > z critical value then reject the null hypothesis.
#
# **3-Two Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ≠μ0
#
# **Decision Criteria:** If the z statistic > z critical value then reject the null hypothesis.

# %% [markdown]
# #### Two Sample Z Test
#
# A two sample z test is used to check if there is a difference between the means of two samples. The z test statistic formula is given as follows:

# %%
Image(filename="C:/Users/MBR/Desktop/bb.jpg", width=400 , height=400)

# %% [markdown]
# **Where:**
#
# **x̄1 and x̄2** are the means of two samples.
#
# **μ1** is the mean of the first population.
#
# **μ2**is the mean of the second population.
#
# **σ1** is the standard deviation first population.
#
# **σ2** is the standard deviation first population.
#
# **n1** is the number of the data points in the first sample.
#
# **n2** is the number of the data points in the second sample.

# %% [markdown]
# ### z-test applications
#
# 1-Z-test is performed in studies where the sample size is larger, and the variance is known.
#
# 2-It is also used to determine if there is a significant difference between the mean of two independent samples.
#
# 3-The z-test can also be used to compare the population proportion to an assumed proportion or to determine
#
# the difference between the population proportion of two samples.

# %% [markdown]
# ## T-test

# %% [markdown]
# ### T-test definition
#
# 1-The t-test is a test in statistics that is used for testing hypotheses regarding
#
# the mean of a small sample taken population when the standard deviation of the population is not known.
#
# 2-The t-test is used to determine if there is a significant difference between the means of two groups.
#
# 3-The t-test is used for hypothesis testing to determine whether a process has an effect on both samples or if the groups are different from each other.
#
# 4-Basically, the t-test allows the comparison of the mean of two sets of data and the determination if the two sets are derived from the same population.
#
# 5-After the null and alternative hypotheses are established, t-test formulas are used to calculate values that are then compared with standard values.
#
# 6-Based on the comparison, the null hypothesis is either rejected or accepted.
#
# 7-The T-test is similar to other tests like the z-test and f-test except that t-test is usually performed in cases where the sample size is small (n≤30).

# %% [markdown]
# ### T-test formula
#
# The T test formula to set up the required hypothesis tests for a one sample and a two-sample T test are given below:

# %% [markdown]
# #### One-Sample T Test
#
# A one-sample t-test is used to determine if the sample is significantly different from the population.
# The formula for the one-sample t-test statistic is given as follows:

# %%
from IPython.display import Image
Image(filename="C:/Users/MBR/Desktop/dd.png", width=400 , height=400)

# %% [markdown]
# **Where:**
#
#  **x̄** is the mean of the sample.
#
#  **µ** is the assumed mean.
#
#  **S** is the standard deviation.
#
#  **n** is the number of observations.
#
# **The algorithm to set a one sample T test based on the T test statistic is given as follows:**
#
# **1-Left Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ<μ0
#
# **Decision Criteria:** If we consider µ = 100 and if our sample mean deviates significantly from 100 towards
#
# the **lower** direction, H0 or null hypothesis is rejected. Otherwise, H0 is accepted at a given level of significance.
#
# **2-Right Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ>μ0
#
# **Decision Criteria:** In this case, when µ = 100 and the sample mean deviates significantly from 100 in
#
# the **upward** direction, H0 is rejected otherwise, it is to be accepted.
#
# **3-Two Tailed Test:**
#
# Null Hypothesis: H0
# : μ=μ0
#
# Alternate Hypothesis: H1
# : μ≠μ0 which may mean µ > µ0 or µ < µ0.
#
# **Decision Criteria:** In a two-tailed test, there are two rejection regions, one in either direction, left and right, towards each tail of the curve.
#
# Suppose, we take µ = 100 and if our sample mean deviates significantly from 100 in either direction, the null hypothesis can be rejected. But if the sample mean does not deviate considerably from µ, the null hypothesis is accepted.

# %% [markdown]
# #### Two Sample T Test
#
# A two sample T test is used to check if there is a difference between the means of two samples. The T test statistic formula is given as follows:

# %%
Image(filename="C:/Users/MBR/Desktop/dd.jpg", width=800 , height=800)

# %% [markdown]
# **Where:**
#
# **x̄1 and x̄2** are the means of two samples.
#
# **μ1** is the mean of the first population.
#
# **μ2**is the mean of the second population.
#
# **S1** is the standard deviation first population.
#
# **S2** is the standard deviation first population.
#
# **n1** is the number of the data points in the first sample.
#
# **n2** is the number of the data points in the second sample.

# %% [markdown]
# ### T-test applications
#
# 1-The T-test is used to compare the mean of two samples, dependent or independent.
#
# 2-It can also be used to determine if the sample mean is different from the assumed mean.
#
# 3-T-test has an application in determining the confidence interval for a sample mean.

# %% [markdown]
# ## Z Test vs T-Test
#
# Both z test and t-test are univariate tests used on the means of two datasets. The differences between both tests are outlined in the table given below:

# %%
Image(filename="C:/Users/MBR/Desktop/hh.jpg", width=600 , height=600)

# %% [markdown]
# ## Chi-square Test

# %% [markdown]
# ### What is a Chi-square test?
#
# 1- A Chi-square test is performed to determine if there is a difference between the theoretical population parameter and the observed data.
#
# 2-Chi-square test is a non-parametric test where the data is not assumed to be normally distributed but is distributed in a chi-square fashion.
#
# 3-It allows the researcher to test factors like a number of factors like the goodness of fit, the significance of population variance, and the homogeneity or difference in population variance.
#
# 4-This test is commonly used to determine if a random sample is drawn from a population with mean **µ** and the variance **σ^2**.

# %% [markdown]
# ### Chi-square test uses
#
# Chi-square test is performed for various purposes, some of which are:
#
# 1-This method is commonly used by researchers to determine the differences between different categorical variables in a population.
#
# 2-A Chi-square test can also be used as a test for goodness of fit. It enables us to observe how well the theoretical distribution fits the observed distribution.
#
# 3-It also works as a test of independence where it enables the researcher to determine if two attributes of a population are associated or not.

# %% [markdown]
# ### Chi-square test formula
#
# Chi-square test is symbolically written as χ2 and the formula of chi-square for comparing variance is given as:

# %%
Image(filename="C:/Users/MBR/Desktop/Chi-square-test.jpg", width=600 , height=600)

# %% [markdown]
# **where:**
#
# **σs^2:** is the variance of the sample.
#
# **σp^2:** is the variance of the sample.
#
# Similarly, when chi-square is used as a non-parametric test for testing the goodness of fit or for testing the independence, the following formula is used:

# %%
Image(filename="C:/Users/MBR/Desktop/Chi-square-test2.jpg", width=600 , height=600)

# %% [markdown]
# **Where:**
#
# **Oij:** is the observed frequency of the cell in the **i** row and **j** column.
#
# **Eij:** is the expected frequency of the cell in the **i** row and **j** column.

# %% [markdown]
# **Chi-square table**
#
# The following is the chi-square distribution table:

# %%
Image(filename="C:/Users/MBR/Desktop/Chi-square-table.jpg", width=600 , height=600)

# %% [markdown]
# ### Conditions for the chi-square test
#
# For the chi-square test to be performed, the following conditions are to be satisfied:
#
# 1-The observations are to be recorded and collected on a random basis.
#
# 2-The items in the samples should all be independent.
#
# 3-The frequencies of data in a group should not be less than 10. Under such conditions, regrouping of items should be done by combining frequencies.
#
# 4-The total number of individual items in the sample should also be reasonably large, about 50 or more.
#
# 5-The constraints in the frequencies should be linear and not containing squares or higher powers.

# %% [markdown]
# ### Chi-square test applications
#
# 1- A Chi-square test is used in cryptanalysis to determine the distribution of plain text and decrypted ciphertext.
#
# 2- Similarly, it is also used in bioinformatics to determine the distribution of different genes like disease genes and other important genes.
#
# 3-A Chi-square test is performed by various researchers of different fields to test the minor or major hypothesis.
